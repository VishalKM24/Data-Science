# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
img = Image.open("panda.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x900 at 0x20F28C6FA08>

# %%
small = img.resize((400, 300))

# %%
small
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x20F28CC5C88>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
type(small)
# Out:
# PIL.Image.Image

# %%
panda = np.array(small)

# %%
panda
# Out:
# array([[[ 72,  88,  39],
#         [ 71,  87,  40],
#         [ 64,  79,  34],
#         ...,
#         [129, 132, 149],
#         [131, 134, 151],
#         [132, 135, 152]],
#
#        [[ 73,  88,  34],
#         [ 74,  88,  36],
#         [ 72,  86,  36],
#         ...,
#         [130, 133, 150],
#         [131, 134, 151],
#         [132, 135, 152]],
#
#        [[ 68,  82,  24],
#         [ 69,  83,  26],
#         [ 68,  82,  27],
#         ...,
#         [134, 137, 154],
#         [134, 137, 154],
#         [135, 138, 155]],
#
#        ...,
#
#        [[ 96,  99, 116],
#         [ 92,  95, 112],
#         [ 90,  93, 110],
#         ...,
#         [ 88,  89,  94],
#         [ 85,  86,  90],
#         [ 82,  82,  87]],
#
#        [[ 95,  98, 115],
#         [ 92,  95, 112],
#         [ 90,  93, 110],
#         ...,
#         [ 85,  87,  89],
#         [ 81,  84,  84],
#         [ 77,  81,  81]],
#
#        [[ 94,  97, 114],
#         [ 92,  95, 112],
#         [ 90,  93, 110],
# ...

# %%
panda.shape
# Out:
# (300, 400, 3)

# %%
plt.imshow(panda)

# %%
plt.imshow(panda[50:250,100:300])

# %%
panda[:, :, 1:] = 0

# %%
plt.imshow(panda)
