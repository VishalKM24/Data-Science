# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img = Image.open("shapes.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x400 at 0x2481D094B88>

# %%
small = np.array(img)

# %%
red = small[:, :, 0]
blue = small[:, :, 1]
green = small[:, :, 2]

# %%
plt.imshow(blue, cmap="gray")

# %%
img = np.zeros((90, 90, 3), dtype=np.uint8)

# %%
img[:30, :] = (255, 0, 0)
img[30:60, :] = (0, 255, 0)
img[60:, :] = (0, 0, 255)

# %%
plt.imshow(img)

# %%
img = np.zeros((90, 90, 3), dtype=np.uint8)

# %%
img[:30, :] = (255, 0, 0)
img[30:60, :] = (0, 255, 0)
img[60:, :] = (0, 0, 255)

img[20:-20,20:-20] = (0, 152, 23)

# %%
plt.imshow(img)

# %%
x = y = np.arange(10,14).reshape(4, 1)

# %%
y = np.arange(0,4)

# %%
x
# Out:
# array([[10],
#        [11],
#        [12],
#        [13]])

# %%
y
# Out:
# array([0, 1, 2, 3])

# %%
x + y
# Out:
# array([[10, 11, 12, 13],
#        [11, 12, 13, 14],
#        [12, 13, 14, 15],
#        [13, 14, 15, 16]])

# %%
img = np.ones((90, 90, 3), dtype=np.uint8)

# %%
img = img*4

# %%
plt.imshow(img)
